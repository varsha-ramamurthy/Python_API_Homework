# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
import api_keys

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # Replace spaces with %20 to create url correctly 
    city = city.replace(" ", "%20")
    

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 619

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# OpenWeatherMap API Key
api_key = api_keys.api_key

# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key

# Create empty lists to append the API data into lists 
city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

# Start the call counter 
record = 1

# Log file print statement
print(f"Beginning Data Retrieval")
print(f"-------------------------------")

#Loop through the cities in the city list 
for city in cities:  
    print(city)
    # Try statement to append calls where value is found 
    # Not all calls return data as OpenWeatherMap will not have have records in all the cities generated by CityPy module
    try: 
        response = requests.get(f"{url}&q={city}").json() 
        city_name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        max_temp.append(response["main"]["temp_max"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        wind_speed.append(response["wind"]["speed"])
        city_record = response["name"]
        print(f"Processing Record {record} | {city_record}")
        print(f"{url}&q={city}")
        
        # Increase counter by one 
        record= record + 1
        
        # Wait a second in loop to not over exceed rate limit of API
        time.sleep(1.01)
        
    # If no record found "skip" to next call
    except:
        print("City not found. Skipping...")
    continue
# Out:
# Beginning Data Retrieval
# -------------------------------
# ascension
# City not found. Skipping...
# yovon
# Processing Record 1 | Yovon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=yovon
# athabasca
# Processing Record 2 | Athabasca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=athabasca
# namatanai
# Processing Record 3 | Namatanai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=namatanai
# saldanha
# Processing Record 4 | Saldanha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=saldanha
# bluff
# Processing Record 5 | Bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=bluff
# ushuaia
# Processing Record 6 | Ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=ushuaia
# balao
# Processing Record 7 | Balao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=balao
# qaanaaq
# Processing Record 8 | Qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=qaanaaq
# artyk
# City not found. Skipping...
# sisimiut
# Processing Record 9 | Sisimiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=sisimiut
# srednekolymsk
# Processing Record 10 | Srednekolymsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=srednekolymsk
# bethel
# Processing Record 11 | Bethel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=bethel
# khatanga
# Processing Record 12 | Khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=khatanga
# dikson
# Processing Record 13 | Dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=dikson
# byron%20bay
# Processing Record 14 | Byron Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=byron%20bay
# zambezi
# Processing Record 15 | Zambezi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=zambezi
# buala
# Processing Record 16 | Buala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=buala
# solnechnyy
# Processing Record 17 | Solnechnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=solnechnyy
# avarua
# Processing Record 18 | Avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=avarua
# ishigaki
# Processing Record 19 | Ishigaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=ishigaki
# grand%20bank
# Processing Record 20 | Grand Bank
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=grand%20bank
# chagda
# City not found. Skipping...
# albany
# Processing Record 21 | Albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=albany
# butaritari
# Processing Record 22 | Butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=butaritari
# kyren
# Processing Record 23 | Kyren
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=kyren
# saint-philippe
# Processing Record 24 | Saint-Philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=saint-philippe
# fairbanks
# Processing Record 25 | Fairbanks
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=fairbanks
# port%20elizabeth
# Processing Record 26 | Port Elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=port%20elizabeth
# okha
# Processing Record 27 | Okha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=okha
# tasiilaq
# Processing Record 28 | Tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=tasiilaq
# anamur
# Processing Record 29 | Anamur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=anamur
# umba
# Processing Record 30 | Umba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=umba
# okhotsk
# Processing Record 31 | Okhotsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=okhotsk
# roma
# Processing Record 32 | Rome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=roma
# arraial%20do%20cabo
# Processing Record 33 | Arraial do Cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=arraial%20do%20cabo
# ilulissat
# Processing Record 34 | Ilulissat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=ilulissat
# anadyr
# Processing Record 35 | Anadyr
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=anadyr
# rikitea
# Processing Record 36 | Rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=rikitea
# marsa%20matruh
# Processing Record 37 | Marsa Matruh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=marsa%20matruh
# san%20antonio
# Processing Record 38 | San Antonio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=san%20antonio
# tommot
# Processing Record 39 | Tommot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=tommot
# puerto%20ayora
# Processing Record 40 | Puerto Ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=puerto%20ayora
# san%20jeronimo
# Processing Record 41 | San Jeronimo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=san%20jeronimo
# tabas
# Processing Record 42 | Tabas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=tabas
# whitehorse
# Processing Record 43 | Whitehorse
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=whitehorse
# barawe
# City not found. Skipping...
# taolanaro
# City not found. Skipping...
# punta%20arenas
# Processing Record 44 | Punta Arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=punta%20arenas
# corumba
# Processing Record 45 | Corumba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=corumba
# paamiut
# Processing Record 46 | Paamiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=paamiut
# mao
# Processing Record 47 | Mao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=mao
# nyurba
# Processing Record 48 | Nyurba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=nyurba
# tuatapere
# Processing Record 49 | Tuatapere
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=tuatapere
# port-gentil
# Processing Record 50 | Port-Gentil
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=port-gentil
# attawapiskat
# City not found. Skipping...
# busselton
# Processing Record 51 | Busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=busselton
# pangnirtung
# Processing Record 52 | Pangnirtung
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=pangnirtung
# east%20london
# Processing Record 53 | East London
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=east%20london
# lebu
# Processing Record 54 | Lebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=lebu
# arlit
# Processing Record 55 | Arlit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=arlit
# rio%20branco
# Processing Record 56 | Rio Branco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=rio%20branco
# bredasdorp
# Processing Record 57 | Bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=bredasdorp
# sao%20joao%20da%20barra
# Processing Record 58 | Sao Joao da Barra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=sao%20joao%20da%20barra
# nikolskoye
# Processing Record 59 | Nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=nikolskoye
# hilo
# Processing Record 60 | Hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=hilo
# severo-kurilsk
# Processing Record 61 | Severo-Kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=severo-kurilsk
# upernavik
# Processing Record 62 | Upernavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=upernavik
# valentin%20gomez%20farias
# Processing Record 63 | Valentin Gomez Farias
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=valentin%20gomez%20farias
# mocuba
# Processing Record 64 | Mocuba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=mocuba
# alice%20springs
# Processing Record 65 | Alice Springs
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=alice%20springs
# kencong
# Processing Record 66 | Kencong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=kencong
# atuona
# Processing Record 67 | Atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=atuona
# jubayl
# City not found. Skipping...
# cayenne
# Processing Record 68 | Cayenne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=cayenne
# tifton
# Processing Record 69 | Tifton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=tifton
# mananara
# City not found. Skipping...
# wewak
# Processing Record 70 | Wewak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=wewak
# tuktoyaktuk
# Processing Record 71 | Tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=tuktoyaktuk
# vao
# Processing Record 72 | Vao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=vao
# talnakh
# Processing Record 73 | Talnakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=talnakh
# opoczno
# Processing Record 74 | Opoczno
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=opoczno
# mopti
# Processing Record 75 | Mopti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=mopti
# rurrenabaque
# Processing Record 76 | Rurrenabaque
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=rurrenabaque
# armacao%20dos%20buzios
# City not found. Skipping...
# zhezkazgan
# Processing Record 77 | Zhezkazgan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=zhezkazgan
# havre-saint-pierre
# Processing Record 78 | Havre-Saint-Pierre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=havre-saint-pierre
# karaul
# City not found. Skipping...
# iqaluit
# Processing Record 79 | Iqaluit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=iqaluit
# constitucion
# Processing Record 80 | Constitucion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=constitucion
# winneba
# Processing Record 81 | Winneba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=winneba
# ust-kulom
# Processing Record 82 | Ust-Kulom
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=ust-kulom
# polunochnoye
# Processing Record 83 | Polunochnoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=polunochnoye
# chuy
# Processing Record 84 | Chuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=chuy
# nikel
# Processing Record 85 | Nikel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=nikel
# thompson
# Processing Record 86 | Thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=thompson
# saint-francois
# Processing Record 87 | Saint-Francois
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=saint-francois
# port-cartier
# Processing Record 88 | Port-Cartier
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=port-cartier
# luderitz
# Processing Record 89 | Luderitz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=luderitz
# magdalena
# Processing Record 90 | Magdalena
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=magdalena
# shingu
# Processing Record 91 | Shingu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=shingu
# hithadhoo
# Processing Record 92 | Hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=hithadhoo
# kinarut
# Processing Record 93 | Kinarut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=kinarut
# sao%20filipe
# Processing Record 94 | Sao Filipe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=sao%20filipe
# cayhagan
# Processing Record 95 | Cayhagan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=cayhagan
# tilichiki
# Processing Record 96 | Tilichiki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=tilichiki
# amderma
# City not found. Skipping...
# zhitikara
# City not found. Skipping...
# luganville
# Processing Record 97 | Luganville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=luganville
# ponta%20do%20sol
# Processing Record 98 | Ponta do Sol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=ponta%20do%20sol
# nanortalik
# Processing Record 99 | Nanortalik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=nanortalik
# barentsburg
# City not found. Skipping...
# hobart
# Processing Record 100 | Hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=hobart
# galesong
# Processing Record 101 | Galesong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=galesong
# kolno
# Processing Record 102 | Kolno
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=kolno
# ust-maya
# Processing Record 103 | Ust-Maya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=ust-maya
# longyearbyen
# Processing Record 104 | Longyearbyen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=longyearbyen
# geraldton
# Processing Record 105 | Geraldton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=geraldton
# noumea
# Processing Record 106 | Noumea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=noumea
# murgab
# Processing Record 107 | Murgab
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=murgab
# richards%20bay
# Processing Record 108 | Richards Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=richards%20bay
# coihaique
# Processing Record 109 | Coihaique
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=coihaique
# leningradskiy
# Processing Record 110 | Leningradskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=leningradskiy
# south%20lake%20tahoe
# Processing Record 111 | South Lake Tahoe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=south%20lake%20tahoe
# sakakah
# City not found. Skipping...
# vaini
# Processing Record 112 | Vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=vaini
# mar%20del%20plata
# Processing Record 113 | Mar del Plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=mar%20del%20plata
# ginir
# Processing Record 114 | Ginir
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=ginir
# jamestown
# Processing Record 115 | Jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=jamestown
# finnsnes
# Processing Record 116 | Finnsnes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=finnsnes
# ayan
# Processing Record 117 | Ayan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=ayan
# saleaula
# City not found. Skipping...
# xuddur
# Processing Record 118 | Xuddur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=xuddur
# port%20alfred
# Processing Record 119 | Port Alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=port%20alfred
# hambantota
# Processing Record 120 | Hambantota
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=hambantota
# kungurtug
# Processing Record 121 | Kungurtug
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=kungurtug
# aklavik
# Processing Record 122 | Aklavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=aklavik
# erzin
# Processing Record 123 | Erzin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=erzin
# yellowknife
# Processing Record 124 | Yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=yellowknife
# barrow
# Processing Record 125 | Barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=barrow
# kumluca
# Processing Record 126 | Kumluca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=kumluca
# kapaa
# Processing Record 127 | Kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=kapaa
# lavrentiya
# Processing Record 128 | Lavrentiya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=lavrentiya
# umm%20kaddadah
# Processing Record 129 | Umm Kaddadah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=umm%20kaddadah
# pisco
# Processing Record 130 | Pisco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=pisco
# isangel
# Processing Record 131 | Isangel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=isangel
# kimbe
# Processing Record 132 | Kimbe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=kimbe
# pacific%20grove
# Processing Record 133 | Pacific Grove
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=pacific%20grove
# korla
# City not found. Skipping...
# esperance
# Processing Record 134 | Esperance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=esperance
# kuminskiy
# Processing Record 135 | Kuminskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=kuminskiy
# buluang
# Processing Record 136 | Buluang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=buluang
# meyungs
# City not found. Skipping...
# maningrida
# Processing Record 137 | Maningrida
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=maningrida
# provideniya
# Processing Record 138 | Provideniya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=provideniya
# san%20patricio
# Processing Record 139 | San Patricio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=san%20patricio
# alibag
# Processing Record 140 | Alibag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=alibag
# vila%20franca%20do%20campo
# Processing Record 141 | Vila Franca do Campo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=vila%20franca%20do%20campo
# utiroa
# City not found. Skipping...
# torbay
# Processing Record 142 | Torbay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=torbay
# bonawon
# Processing Record 143 | Bonawon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=bonawon
# saint%20george
# Processing Record 144 | Saint George
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=saint%20george
# comodoro%20rivadavia
# Processing Record 145 | Comodoro Rivadavia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=comodoro%20rivadavia
# katsuura
# Processing Record 146 | Katsuura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=katsuura
# cape%20town
# Processing Record 147 | Cape Town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=cape%20town
# yar-sale
# Processing Record 148 | Yar-Sale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=yar-sale
# deputatskiy
# Processing Record 149 | Deputatskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=deputatskiy
# vardo
# Processing Record 150 | Vardo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=vardo
# hermanus
# Processing Record 151 | Hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=hermanus
# along
# Processing Record 152 | Along
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=along
# gurgan
# City not found. Skipping...
# hirosaki
# Processing Record 153 | Hirosaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=hirosaki
# seddon
# Processing Record 154 | Seddon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=seddon
# gweru
# Processing Record 155 | Gweru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=gweru
# lhokseumawe
# Processing Record 156 | Lhokseumawe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=lhokseumawe
# saint-georges
# Processing Record 157 | Saint-Georges
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=saint-georges
# hobe%20sound
# Processing Record 158 | Hobe Sound
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=hobe%20sound
# lata
# Processing Record 159 | Lata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=lata
# winnemucca
# Processing Record 160 | Winnemucca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=winnemucca
# cidreira
# Processing Record 161 | Cidreira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=cidreira
# praia%20da%20vitoria
# Processing Record 162 | Praia da Vitoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=praia%20da%20vitoria
# pevek
# Processing Record 163 | Pevek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=pevek
# new%20norfolk
# Processing Record 164 | New Norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=new%20norfolk
# sobolevo
# Processing Record 165 | Sobolevo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=sobolevo
# san%20vicente
# Processing Record 166 | San Vicente
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=san%20vicente
# tazovskiy
# Processing Record 167 | Tazovskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=tazovskiy
# do%20gonbadan
# Processing Record 168 | Do Gonbadan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=do%20gonbadan
# mys%20shmidta
# City not found. Skipping...
# humaita
# Processing Record 169 | Humaita
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=humaita
# vanimo
# Processing Record 170 | Vanimo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=vanimo
# saint%20anthony
# Processing Record 171 | Saint Anthony
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=saint%20anthony
# ossora
# Processing Record 172 | Ossora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=ossora
# bajo%20baudo
# City not found. Skipping...
# sept-iles
# Processing Record 173 | Sept-Iles
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=sept-iles
# faya
# Processing Record 174 | Faya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=faya
# yulara
# Processing Record 175 | Yulara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=yulara
# yichang
# Processing Record 176 | Yichang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=yichang
# alyangula
# Processing Record 177 | Alyangula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=alyangula
# bandarbeyla
# Processing Record 178 | Bandarbeyla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=bandarbeyla
# beira
# Processing Record 179 | Beira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=beira
# mataura
# Processing Record 180 | Mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=mataura
# alta%20floresta
# Processing Record 181 | Alta Floresta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=alta%20floresta
# xiangdong
# City not found. Skipping...
# bambous%20virieux
# Processing Record 182 | Bambous Virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=bambous%20virieux
# wagar
# Processing Record 183 | Wagar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=wagar
# nome
# Processing Record 184 | Nome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=nome
# krasnokholm
# Processing Record 185 | Krasnokholm
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=krasnokholm
# tomatlan
# Processing Record 186 | Tomatlan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=tomatlan
# saint%20pete%20beach
# Processing Record 187 | Saint Pete Beach
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=saint%20pete%20beach
# samusu
# City not found. Skipping...
# sapao
# City not found. Skipping...
# haicheng
# Processing Record 188 | Haicheng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=haicheng
# kamenskoye
# City not found. Skipping...
# ballina
# Processing Record 189 | Ballina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=ballina
# wonthaggi
# Processing Record 190 | Wonthaggi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=wonthaggi
# nueva%20loja
# Processing Record 191 | Nueva Loja
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=nueva%20loja
# carnarvon
# Processing Record 192 | Carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=carnarvon
# mulchen
# Processing Record 193 | Mulchen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=mulchen
# crnomelj
# Processing Record 194 | Crnomelj
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=crnomelj
# santiago
# Processing Record 195 | Santiago
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=santiago
# grand%20river%20south%20east
# City not found. Skipping...
# hasaki
# Processing Record 196 | Hasaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=hasaki
# lasa
# Processing Record 197 | Lasa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=lasa
# tiksi
# Processing Record 198 | Tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=tiksi
# maryborough
# Processing Record 199 | Maryborough
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=maryborough
# severnyy-kospashskiy
# Processing Record 200 | Severnyy-Kospashskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=severnyy-kospashskiy
# narsaq
# Processing Record 201 | Narsaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=narsaq
# novopokrovka
# Processing Record 202 | Novopokrovka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=novopokrovka
# vostok
# Processing Record 203 | Vostok
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=vostok
# sampit
# Processing Record 204 | Sampit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=sampit
# nazret
# Processing Record 205 | Nazret
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=nazret
# codrington
# Processing Record 206 | Codrington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=codrington
# iranshahr
# Processing Record 207 | Iranshahr
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=iranshahr
# georgetown
# Processing Record 208 | Georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=georgetown
# fortuna
# Processing Record 209 | Fortuna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=fortuna
# tumannyy
# City not found. Skipping...
# simbahan
# Processing Record 210 | Simbahan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=simbahan
# verkhnevilyuysk
# Processing Record 211 | Verkhnevilyuysk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=verkhnevilyuysk
# marzuq
# Processing Record 212 | Marzuq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=marzuq
# sur
# Processing Record 213 | Sur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=sur
# kamenka
# Processing Record 214 | Kamenka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=kamenka
# malwan
# City not found. Skipping...
# castro
# Processing Record 215 | Castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=castro
# cherskiy
# Processing Record 216 | Cherskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=cherskiy
# inderborskiy
# City not found. Skipping...
# kahului
# Processing Record 217 | Kahului
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=kahului
# grindavik
# Processing Record 218 | Grindavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=grindavik
# karkaralinsk
# City not found. Skipping...
# mahajanga
# Processing Record 219 | Mahajanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=mahajanga
# olinda
# Processing Record 220 | Olinda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=olinda
# taoru
# Processing Record 221 | Taoru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=taoru
# souillac
# Processing Record 222 | Souillac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=souillac
# naze
# Processing Record 223 | Naze
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=naze
# ahipara
# Processing Record 224 | Ahipara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=ahipara
# cockburn%20harbour
# City not found. Skipping...
# shwebo
# Processing Record 225 | Shwebo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=shwebo
# mahebourg
# Processing Record 226 | Mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=mahebourg
# chokurdakh
# Processing Record 227 | Chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=chokurdakh
# kiunga
# Processing Record 228 | Kiunga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=kiunga
# alberton
# Processing Record 229 | Alberton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=alberton
# yeniseysk
# Processing Record 230 | Yeniseysk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=yeniseysk
# guerrero%20negro
# Processing Record 231 | Guerrero Negro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=guerrero%20negro
# dali
# Processing Record 232 | Dali
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=dali
# terre%20haute
# Processing Record 233 | Terre Haute
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=terre%20haute
# belushya%20guba
# City not found. Skipping...
# paita
# Processing Record 234 | Paita
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=paita
# kandrian
# Processing Record 235 | Kandrian
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=kandrian
# hyeres
# Processing Record 236 | Hyeres
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=hyeres
# mwense
# Processing Record 237 | Mwense
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=mwense
# simao
# Processing Record 238 | Simao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=simao
# ulaangom
# Processing Record 239 | Ulaangom
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=ulaangom
# graaff-reinet
# Processing Record 240 | Graaff-Reinet
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=graaff-reinet
# mangan
# Processing Record 241 | Mangan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=mangan
# illoqqortoormiut
# City not found. Skipping...
# mawlaik
# Processing Record 242 | Mawlaik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=mawlaik
# inhambane
# Processing Record 243 | Inhambane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=inhambane
# doctor%20pedro%20p.%20pena
# City not found. Skipping...
# andenes
# City not found. Skipping...
# bumba
# Processing Record 244 | Bumba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=bumba
# deh%20rawud
# City not found. Skipping...
# brae
# Processing Record 245 | Brae
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=brae
# tiarei
# Processing Record 246 | Tiarei
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=tiarei
# hongjiang
# Processing Record 247 | Hongjiang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=hongjiang
# nantucket
# Processing Record 248 | Nantucket
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=nantucket
# muravlenko
# Processing Record 249 | Muravlenko
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=muravlenko
# padang
# Processing Record 250 | Padang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=padang
# phan%20rang
# City not found. Skipping...
# pochutla
# Processing Record 251 | Pochutla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=pochutla
# felidhoo
# City not found. Skipping...
# sakata
# Processing Record 252 | Sakata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=sakata
# seoul
# Processing Record 253 | Seoul
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=seoul
# kodiak
# Processing Record 254 | Kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=kodiak
# rosamorada
# Processing Record 255 | Rosamorada
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=rosamorada
# sinkat
# City not found. Skipping...
# kangalassy
# Processing Record 256 | Kangalassy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=kangalassy
# ulaanbaatar
# Processing Record 257 | Ulaanbaatar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=ulaanbaatar
# kavieng
# Processing Record 258 | Kavieng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=kavieng
# el%20balyana
# City not found. Skipping...
# saint-augustin
# Processing Record 259 | Saint-Augustin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=saint-augustin
# los%20llanos%20de%20aridane
# Processing Record 260 | Los Llanos de Aridane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=los%20llanos%20de%20aridane
# hengshui
# Processing Record 261 | Hengshui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=hengshui
# abnub
# Processing Record 262 | Abnub
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=abnub
# panaba
# Processing Record 263 | Panaba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=panaba
# mmabatho
# Processing Record 264 | Mmabatho
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=mmabatho
# faanui
# Processing Record 265 | Faanui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=faanui
# nizhneyansk
# City not found. Skipping...
# touros
# Processing Record 266 | Touros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=touros
# teacapan
# Processing Record 267 | Teacapan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=teacapan
# mailsi
# Processing Record 268 | Mailsi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=mailsi
# sao%20mateus
# Processing Record 269 | Sao Mateus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=sao%20mateus
# thap%20than
# Processing Record 270 | Thap Than
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=thap%20than
# puerto%20escondido
# Processing Record 271 | Puerto Escondido
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=puerto%20escondido
# kalat
# Processing Record 272 | Kalat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=kalat
# kieta
# Processing Record 273 | Kieta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=kieta
# ribeira%20grande
# Processing Record 274 | Ribeira Grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=ribeira%20grande
# kavaratti
# Processing Record 275 | Kavaratti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=kavaratti
# lac-megantic
# Processing Record 276 | Lac-Megantic
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=lac-megantic
# bilma
# Processing Record 277 | Bilma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=bilma
# klaksvik
# Processing Record 278 | Klaksvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=klaksvik
# dharchula
# Processing Record 279 | Dharchula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=dharchula
# skara
# Processing Record 280 | Skara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=skara
# cheuskiny
# City not found. Skipping...
# mozarlandia
# Processing Record 281 | Mozarlandia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=mozarlandia
# gigmoto
# Processing Record 282 | Gigmoto
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=gigmoto
# clyde%20river
# Processing Record 283 | Clyde River
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=clyde%20river
# gizo
# Processing Record 284 | Gizo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=gizo
# ust-kamchatsk
# City not found. Skipping...
# aflu
# City not found. Skipping...
# wajid
# Processing Record 285 | Wajid
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=wajid
# bougouni
# Processing Record 286 | Bougouni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=bougouni
# tsihombe
# City not found. Skipping...
# swinoujscie
# Processing Record 287 | Swinoujscie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=swinoujscie
# miles%20city
# Processing Record 288 | Miles City
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=miles%20city
# taoudenni
# Processing Record 289 | Taoudenni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=taoudenni
# ostersund
# Processing Record 290 | Ostersund
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=ostersund
# urdzhar
# City not found. Skipping...
# cervo
# Processing Record 291 | Cervo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=cervo
# bonthe
# Processing Record 292 | Bonthe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=bonthe
# margate
# Processing Record 293 | Margate
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=margate
# urumqi
# City not found. Skipping...
# cabo%20san%20lucas
# Processing Record 294 | Cabo San Lucas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=cabo%20san%20lucas
# lompoc
# Processing Record 295 | Lompoc
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=lompoc
# koboldo
# City not found. Skipping...
# caluquembe
# Processing Record 296 | Caluquembe
# ...
# iguape
# Processing Record 455 | Iguape
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=iguape
# sentyabrskiy
# City not found. Skipping...
# funadhoo
# Processing Record 456 | Funadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=funadhoo
# norman%20wells
# Processing Record 457 | Norman Wells
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=norman%20wells
# lac%20du%20bonnet
# Processing Record 458 | Lac du Bonnet
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=lac%20du%20bonnet
# hingoli
# Processing Record 459 | Hingoli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=hingoli
# shchelyayur
# City not found. Skipping...
# merate
# Processing Record 460 | Merate
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=merate
# saskylakh
# Processing Record 461 | Saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=saskylakh
# fort%20saint%20james
# Processing Record 462 | Fort Saint James
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=fort%20saint%20james
# nkhotakota
# Processing Record 463 | Nkhotakota
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=nkhotakota
# florencia
# Processing Record 464 | Florencia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=florencia
# high%20rock
# Processing Record 465 | High Rock
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=high%20rock
# saint%20helens
# Processing Record 466 | Saint Helens
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=saint%20helens
# shakhtinsk
# Processing Record 467 | Shakhtinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=shakhtinsk
# college
# Processing Record 468 | College
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=college
# imeni%20poliny%20osipenko
# Processing Record 469 | Imeni Poliny Osipenko
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=imeni%20poliny%20osipenko
# dunedin
# Processing Record 470 | Dunedin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=dunedin
# moose%20factory
# Processing Record 471 | Moose Factory
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=moose%20factory
# san%20carlos
# Processing Record 472 | San Carlos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=san%20carlos
# cumnock
# Processing Record 473 | Cumnock
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=cumnock
# weligama
# Processing Record 474 | Weligama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=weligama
# columbia
# Processing Record 475 | Columbia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=columbia
# nalut
# Processing Record 476 | Nalut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=nalut
# paragominas
# Processing Record 477 | Paragominas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=paragominas
# ust-omchug
# Processing Record 478 | Ust-Omchug
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=ust-omchug
# viligili
# City not found. Skipping...
# kumbo
# Processing Record 479 | Kumbo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=kumbo
# nhulunbuy
# Processing Record 480 | Nhulunbuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=nhulunbuy
# dudinka
# Processing Record 481 | Dudinka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=dudinka
# ulladulla
# Processing Record 482 | Ulladulla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=ulladulla
# kegayli
# City not found. Skipping...
# shahr-e%20babak
# Processing Record 483 | Shahr-e Babak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=shahr-e%20babak
# karak
# Processing Record 484 | Karak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=karak
# lake%20city
# Processing Record 485 | Lake City
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=lake%20city
# palabuhanratu
# City not found. Skipping...
# pundaguitan
# Processing Record 486 | Pundaguitan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=pundaguitan
# zlobin
# Processing Record 487 | Zlobin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=zlobin
# tofield
# Processing Record 488 | Tofield
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=tofield
# kande
# Processing Record 489 | Kande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=kande
# general%20roca
# Processing Record 490 | General Roca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=general%20roca
# soyo
# Processing Record 491 | Soyo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=soyo
# shakawe
# Processing Record 492 | Shakawe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=shakawe
# warqla
# City not found. Skipping...
# solwezi
# Processing Record 493 | Solwezi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=solwezi
# chara
# Processing Record 494 | Chara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=chara
# moundsville
# Processing Record 495 | Moundsville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=moundsville
# jevargi
# Processing Record 496 | Jevargi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=jevargi
# pittsburg
# Processing Record 497 | Pittsburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=pittsburg
# krasnyy%20oktyabr
# Processing Record 498 | Krasnyy Oktyabr
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=krasnyy%20oktyabr
# karwar
# Processing Record 499 | Karwar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=karwar
# usinsk
# Processing Record 500 | Usinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=usinsk
# henties%20bay
# Processing Record 501 | Henties Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=henties%20bay
# wynyard
# Processing Record 502 | Wynyard
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=wynyard
# morayfield
# Processing Record 503 | Morayfield
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=morayfield
# jujuy
# City not found. Skipping...
# pafos
# City not found. Skipping...
# yelizovo
# Processing Record 504 | Yelizovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=yelizovo
# kudeyevskiy
# Processing Record 505 | Kudeyevskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=kudeyevskiy
# poltava
# Processing Record 506 | Poltava
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=poltava
# ati
# Processing Record 507 | Ati
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=ati
# cap%20malheureux
# Processing Record 508 | Cap Malheureux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=cap%20malheureux
# parrita
# Processing Record 509 | Parrita
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=parrita
# ambodifototra
# City not found. Skipping...
# dinard
# Processing Record 510 | Dinard
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=dinard
# berezovyy
# Processing Record 511 | Berezovyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=berezovyy
# mouila
# Processing Record 512 | Mouila
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=mouila
# mercedes
# Processing Record 513 | Mercedes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=mercedes
# yining
# Processing Record 514 | Yining
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=yining
# mitsamiouli
# Processing Record 515 | Mitsamiouli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=mitsamiouli
# gisborne
# Processing Record 516 | Gisborne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=gisborne
# beloha
# Processing Record 517 | Beloha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=beloha
# samarkand
# Processing Record 518 | Samarkand
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=samarkand
# tabialan
# City not found. Skipping...
# san%20luis
# Processing Record 519 | San Luis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=san%20luis
# fort%20nelson
# Processing Record 520 | Fort Nelson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=fort%20nelson
# ola
# Processing Record 521 | Ola
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=ola
# barbar
# City not found. Skipping...
# oyama
# Processing Record 522 | Oyama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=oyama
# tigzirt
# Processing Record 523 | Tigzirt
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=tigzirt
# buin
# Processing Record 524 | Buin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=buin
# arkhangelsk
# Processing Record 525 | Arkhangelsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=arkhangelsk
# kaeo
# Processing Record 526 | Kaeo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=kaeo
# iwanai
# Processing Record 527 | Iwanai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=iwanai
# boguchany
# Processing Record 528 | Boguchany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=boguchany
# takoradi
# Processing Record 529 | Takoradi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=takoradi
# kanye
# Processing Record 530 | Kanye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=kanye
# luwingu
# Processing Record 531 | Luwingu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=luwingu
# knysna
# Processing Record 532 | Knysna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=knysna
# lazaro%20cardenas
# Processing Record 533 | Lazaro Cardenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=lazaro%20cardenas
# kantang
# Processing Record 534 | Kantang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=kantang
# central%20point
# Processing Record 535 | Central Point
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=central%20point
# umm%20ruwabah
# City not found. Skipping...
# roald
# Processing Record 536 | Roald
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=roald
# panzhihua
# Processing Record 537 | Panzhihua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=panzhihua
# guerrero
# Processing Record 538 | Guerrero
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=guerrero
# penzance
# Processing Record 539 | Penzance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=penzance
# fez
# Processing Record 540 | Fez
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=fez
# nizwa
# Processing Record 541 | Nizwa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=nizwa
# aripuana
# Processing Record 542 | Aripuana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=aripuana
# bull%20savanna
# Processing Record 543 | Bull Savanna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=bull%20savanna
# mae%20sai
# Processing Record 544 | Mae Sai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=mae%20sai
# shache
# Processing Record 545 | Shache
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=shache
# elizabeth%20city
# Processing Record 546 | Elizabeth City
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=elizabeth%20city
# jiexiu
# Processing Record 547 | Jiexiu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=jiexiu
# solenzo
# Processing Record 548 | Solenzo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=solenzo
# balkhash
# Processing Record 549 | Balkhash
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=balkhash
# ambovombe
# Processing Record 550 | Ambovombe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=ambovombe
# calatayud
# Processing Record 551 | Calatayud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=calatayud
# birao
# Processing Record 552 | Birao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=birao
# pipar
# City not found. Skipping...
# dukat
# Processing Record 553 | Dukat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=164c7f67a8464537c7b75fa0d17af023&q=dukat

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create a dictonary with the lists generated
weatherpy_dict = {
    "City": city_name,
    "Cloudiness":cloudiness, 
    "Country":country,
    "Date":date, 
    "Humidity": humidity,
    "Lat":lat, 
    "Lng":lng, 
    "Max Temp": max_temp,
    "Wind Speed":wind_speed
}

# Create a data frame from dictionary
weather_data = pd.DataFrame(weatherpy_dict)

# Display count of weather data values 
weather_data.count()
# Out:
# City          553
# Cloudiness    553
# Country       553
# Date          553
# Humidity      553
# Lat           553
# Lng           553
# Max Temp      553
# Wind Speed    553
# dtype: int64

# %%
# Save data frame to CSV
weather_data.to_csv('Output_CSV/weather_data.csv')

# Display data frame head 
weather_data.head()
# Out:
#         City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0      Yovon          20      TJ  1561211363        32  38.32   69.05
# 1  Athabasca           2      CA  1561211364        72  54.72 -113.29
# 2  Namatanai         100      PG  1561211366        88  -3.66  152.44
# 3   Saldanha         100      PT  1561211367        21  41.42   -6.55
# 4      Bluff           0      AU  1561211368        65 -23.58  149.07
#
#    Max Temp  Wind Speed
# 0     98.60       20.13
# 1     57.88        6.89
# 2     78.22       13.78
# 3     83.98       14.20
# 4     49.60        3.83

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Max Temp"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature")
plt.ylabel("Max. Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Output_Plots/Max_Temp_vs_Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %% [markdown]
# #### Latitude vs. Wind Speed Plot
